# %%
import numpy as np
import pandas as pd

# %%
students_perf = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
students_perf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance = pd.read_csv('E:\Курсы, которые прохожу СЕЙЧАС\Введение в Data Science и машинное обучение\StudentsPerformance.csv')
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_perf.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_perf[students_perf['math score'] > 95]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 104    male        group C                some college      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 263  female        group E                 high school      standard
# 286    male        group E          associate's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 562    male        group C           bachelor's degree      standard
# ...

# %%
students_perf.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_perf.groupby('gender').aggregate({'math score': 'mean'})
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %%
students_performance.groupby('test preparation course')['math score'].agg(['mean'])
# Out:
#                               mean
# test preparation course
# completed                69.695531
# none                     64.077882

# %% [markdown]
# Methods help us to handle and convert data. Attributes help us to see what is keeping in data.

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_performance.iloc[0:5, 0:3]  # iloc == integer location
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students_performance.iloc[[10, 3, 0], [-3, -2, -1]]
# Out:
#     math score  reading score  writing score
# 10          58             54             52
# 3           47             57             44
# 0           72             72             74

# %%
stud = students_perf.iloc[[0, 3, 4, 7, 8]]
stud
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
stud.index = ['Jane', 'Sasha', 'Max', 'Bob', 'Tom']
stud
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# Jane   female        group B           bachelor's degree      standard
# Sasha    male        group A          associate's degree  free/reduced
# Max      male        group C                some college      standard
# Bob      male        group B                some college  free/reduced
# Tom      male        group D                 high school  free/reduced
#
#       test preparation course  math score  reading score  writing score
# Jane                     none          72             72             74
# Sasha                    none          47             57             44
# Max                      none          76             78             75
# Bob                      none          40             43             39
# Tom                 completed          64             64             67

# %%
stud.loc[['Sasha', 'Jane'], ['gender', 'writing score']]
# Out:
#        gender  writing score
# Sasha    male             44
# Jane   female             74

# %%
stud.iloc[:, 0]
# Out:
# Jane     female
# Sasha      male
# Max        male
# Bob        male
# Tom        male
# Name: gender, dtype: object

# %%
print(type(stud[['gender']]))
print(type(stud['gender']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
one = pd.Series([1, 2], index=['1', '2'])
two = pd.Series([3, 4], index=['1', '2'])
df = pd.DataFrame({'first': one, 'second': two})
df
# Out:
#    first  second
# 1      1       3
# 2      2       4

# %%
students_perf.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %% [markdown]
# [pandas.DataFrame.value_counts](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html)

# %%
students_perf.select_dtypes(include='int')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# [pandas.DataFrame.select_dtypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html)

# %%
titanic = pd.read_csv('E:\Курсы, которые прохожу СЕЙЧАС\Введение в Data Science и машинное обучение\\titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64
